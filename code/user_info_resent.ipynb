# %%
import os
print(os.getcwd())

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# c:\jupyter_home\통합프로젝트\library\code

# %%
import pandas as pd

# %%
cd G:\통합프로젝트\data2
# Out:
# G:\통합프로젝트\data2

# %%
os.listdir('../data2')
# Out:
# ['user_info_11.csv',
#  'user_info_12.csv',
#  'user_info_13.csv',
#  'user_info_14.csv',
#  'user_info_15.csv',
#  'user_info_16.csv',
#  'user_info_17.csv',
#  'user_info_18.csv',
#  'user_info_19.csv',
#  'user_info_20.csv']

# %%
forders = os.listdir('../data2')

# %%
cd ../data2
# Out:
# G:\통합프로젝트\data2

# %%
import os

path = '../data2/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + i, error_bad_lines=False)
    df = pd.concat([df,data])
    
df = df.reset_index(drop = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18543501 entries, 0 to 18543500
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   rec_key      int64
#  1   book_key     int64
#  2   user_key     object
#  3   loan_date    object
#  4   return_date  object
# dtypes: int64(2), object(3)
# memory usage: 707.4+ MB

# %%
display(df.head())
# Out:
#       rec_key    book_key                                  user_key  \
# 0  1822450338  1699774223  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 1  1823175933  1625377432  C0149AC77AF2058BCA3E07FE765A0E30837261EA
# 2  1822450339  1699774321  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3  1823176082  1616331145  E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4  1822450340  1689903085  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
#
#                loan_date            return_date
# 0  2022-03-31 12:00:00.0  2022-04-18 12:00:00.0
# 1  2022-04-19 12:00:00.0  2022-04-21 12:00:00.0
# 2  2022-03-31 12:00:00.0  2022-04-18 12:00:00.0
# 3  2022-04-19 12:00:00.0  2022-04-22 12:00:00.0
# 4  2022-03-31 12:00:00.0  2022-04-18 12:00:00.0

# %%
df.to_csv('../data2/user_info_reset.csv')

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/user_info_reset.csv')
# Out:
# C:\Users\yibob\AppData\Local\Temp\ipykernel_13764\2478813399.py:1: DtypeWarning: Columns (7,8,10,11,12,13,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/user_info_reset.csv')

# %%
df.info()

# %%
df = df[['rec_key','book_key','user_key','loan_date','return_date']]

# %%
df['user_key'].value_counts()
# Out:
# 022FEB738926B92AF180C5165B668D6A1EFA59B3                            4721
# 71D159439125294DDFB88D0E4EFA3FF878E3FD44                            4637
# 52F2E58CB41DCCE478324F9885D358A955E2BA95                            4546
# 2CA8D880CAE18FC3D982DA52162032185CF53F31                            4242
# 92E45478D1031EFDD0C81616DCDA6E473C56035D                            3853
#                                                                     ...
# 3a65da21a403042c11b4459034904145cf33cd07f0a23b574538a6e922fbacd5       1
# c9f342115ac20c6de730bcb532c3b444540f4099a155e44853b41f25f1efb831       1
# d07ef4818b2f9cec3928a79f8c9b32da6172e96a6ce13dc85edaf6fbff615489       1
# 157c5c4f081c871fdcc913ad665e643a6ecd455c0033dab7a05f4898dc28b66a       1
# 2A3036303230303031333330                                               1
# Name: user_key, Length: 1212343, dtype: int64

# %%
print(len(b))
# Out:
# 56034

# %%
a = df['user_key'].value_counts() > 50
b = list(a[a].index)
print(len(b))
# Out:
# 56034

# %%
df[df['book_key'] == 1204091352]
# Out:
#              rec_key    book_key                                  user_key  \
# 0         1822450338  1204091352  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 1         1823175933  1204091352  C0149AC77AF2058BCA3E07FE765A0E30837261EA
# 2         1822450339  1204091352  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3         1823176082  1204091352  E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4         1822450340  1204091352  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# ...              ...         ...                                       ...
# 18543496    21456926  1204091352                  2A3134313230303030303930
# 18543497    21456927  1204091352                  2A3134313230303030303930
# 18543498    21456941  1204091352                  2A3231313130303030343131
# 18543499    21456942  1204091352                  2A3231313130303030343131
# 18543500     9829482  1204091352                  2A3036303230303031333330
#
#                       loan_date            return_date
# ...

# %%
import requests
import json

# %%
url = "https://englib.yangsan.go.kr/search/bookLibInfo.do"
result = requests.get(url)

# %%
with open(result, 'r', encoding='utf8')

# %%
'''
import requests
import pprint
import json

# url 입력
url = 'http://data4library.kr/api/itemSrch/book_code'

# url 불러오기
response = requests.get(url)

#데이터 값 출력해보기
contents = response.text
'''

# %%
import pandas as pd
book_key = pd.read_csv('../data2/book_info.csv')

# %%
book_key.rename(columns = {'BOOK_KEY':'book_key'},inplace=True)
display(book_key.head())
# Out:
#    Unnamed: 0                 TITLE_INFO    SHELF_LOC_NAME           ISBN  \
# 0           0  (드론의 범죄화 시대에 따른) 드론과 안티드론  LH꿈마루[양주동:주공3단지]  9791162571125
# 1           1                패션과 문화, 通하다  LH꿈마루[양주동:주공3단지]  9788958951872
# 2           2                     고양이 수프  LH꿈마루[양주동:주공3단지]  9788961911740
# 3           3           (만화로 읽는) 삼국사기. 1  LH꿈마루[양주동:주공3단지]  9788984975408
# 4           4                 푸른담쟁이 세계문학  LH꿈마루[양주동:주공3단지]  9788901069098
#
#   WORKING_STATUS        REG_NO      LIB_NAME    book_key            CALL_NO  \
# 0        BOL112N  GTC000003295  LH 꿈마루 작은도서관  1204091352     559.34469-오54드
# 1        BOL112N  GTC000003309  LH 꿈마루 작은도서관  1204091471           592-이57패
# 2        BOL112N  GTC000003233  LH 꿈마루 작은도서관  1203686429       유아 331-김292고
# 3        BOL112N  GTC000003251  LH 꿈마루 작은도서관  1204073012  아동 911.03-드298삼-1
# 4        BOL112N  GTC000003239  LH 꿈마루 작은도서관  1204072232    청소년 808-웅78푸-14
#
#    LIB_CODE MANAGE_CODE
# 0    748208          GT
# ...

# %%
user_info = pd.read_csv('../data/user_info_reset.csv')

# %%
book_key = book_key[['book_key','TITLE_INFO']]
display(book_key.head())
# Out:
#      book_key                 TITLE_INFO
# 0  1204091352  (드론의 범죄화 시대에 따른) 드론과 안티드론
# 1  1204091471                패션과 문화, 通하다
# 2  1203686429                     고양이 수프
# 3  1204073012           (만화로 읽는) 삼국사기. 1
# 4  1204072232                 푸른담쟁이 세계문학

# %%
df5 = pd.merge(user_info, book_key, on='book_key', how='inner', suffixes=['_left', '_right'])
display(df5)
# Out:
#      Unnamed: 0    rec_key   book_key  \
# 0        241277  975881895  573960626
# 1        282769  976876233  573967018
# 2        286329  976965787  573969549
# 3        454798  836520147  661645681
# 4        498408  868573198  661645681
# ..          ...        ...        ...
# 221    15985258  679504193  561955963
# 222    15988360  680084605  562912178
# 223    18497648  623629621  611903013
# 224    18504981  623679167  602306369
# 225    18511569  623626713  613090588
#
#                                               user_key              loan_date  \
# 0    75c457c2532150b79c55b4619b98c3d6aaedba48617d31...  2022-03-15 12:00:00.0
# 1    d6776ab3ba90fedab8228a52f9560fee1469adad70b893...  2022-04-10 12:00:00.0
# 2    c45f176c944b6936e722c436a6681ebdfb0fbdf18eab10...  2022-04-13 12:00:00.0
# 3             CFC57C4A5E31172E3694BB44408210079E2E8CD8  2021-09-18 12:00:00.0
# 4             7F2CBC6D5190EBF672C2898BE7C3F7A35C765633  2021-11-16 12:00:00.0
# ...

# %%
display(user_info.head())
# Out:
#    Unnamed: 0     rec_key    book_key  \
# 0           0  1822450338  1699774223
# 1           1  1823175933  1625377432
# 2           2  1822450339  1699774321
# 3           3  1823176082  1616331145
# 4           4  1822450340  1689903085
#
#                                    user_key              loan_date  \
# 0  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F  2022-03-31 12:00:00.0
# 1  C0149AC77AF2058BCA3E07FE765A0E30837261EA  2022-04-19 12:00:00.0
# 2  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F  2022-03-31 12:00:00.0
# 3  E1A7C4AF8B9356CE5A15199E17707545DD7D76DB  2022-04-19 12:00:00.0
# 4  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F  2022-03-31 12:00:00.0
#
#              return_date  lib_code loan_type_code return_type_code  \
# 0  2022-04-18 12:00:00.0      1624              3              3.0
# 1  2022-04-21 12:00:00.0      1623              3              3.0
# 2  2022-04-18 12:00:00.0      1624              3              3.0
# ...

# %%
df5[df5['book_key'] == 646987]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, rec_key, book_key, user_key, loan_date, return_date, lib_code, loan_type_code, return_type_code, return_plan_date, reservation_date, reservation_expire_date, status, l_device, r_device, manage_code, loan_manage_code, return_manage_code, master_lib_code, title_info, TITLE_INFO]
# Index: []
#
# [0 rows x 21 columns]

# %%
user_info['book_key'].value_counts()
# Out:
# 100015913    202
# 100879060    187
# 100879045    187
# 100879021    184
# 100879033    183
#             ...
# 7473476        1
# 9109586        1
# 9002211        1
# 9867545        1
# 125122         1
# Name: book_key, Length: 7682089, dtype: int64

# %%
book_key['book_key'].value_counts()
# Out:
# 1204091352    1
# 570074155     1
# 570072676     1
# 570072688     1
# 570077106     1
#              ..
# 618983906     1
# 618984160     1
# 618985057     1
# 618985149     1
# 1210228152    1
# Name: book_key, Length: 66376, dtype: int64

# %%
user_info[user_info['book_key'] == 646987]
# Out:
#          Unnamed: 0  rec_key  book_key  \
# 3913642     3913642  2760741    646987
#
#                                          user_key              loan_date  \
# 3913642  3BD3BAF7D4EDF371794116410BD2C8E834E61C9B  2021-10-26 12:00:00.0
#
#                    return_date  lib_code loan_type_code return_type_code  \
# 3913642  2022-04-01 12:00:00.0      4600           일반대출             연체반납
#
#               return_plan_date reservation_date reservation_expire_date  \
# 3913642  2021-11-09 12:00:00.0              NaN                     NaN
#
#         status l_device r_device manage_code loan_manage_code  \
# 3913642    대출중     무인기기     무인기기      111314           111314
#
#         return_manage_code  master_lib_code  title_info
# 3913642             111314             4600           0

# %%
user_info['title_info'] = 0

# %%
user_info.loc[(user_info['book_key']).equals(book_key['book_key']), 'title_info'] = book_key['TITLE_INFO']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 user_info.loc[(user_info['book_key']).equals(book_key['book_key']), 'title_info'] = book_key['TITLE_INFO']
#
# File ~\anaconda3\envs\ML_Project_5th\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\envs\ML_Project_5th\lib\site-packages\pandas\core\indexing.py:1600, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1595 for i, idx in enumerate(indexer):
#    1596     if isinstance(idx, dict):
#    1597
#    1598         # reindex the axis to the new value
#    1599         # and set inplace
# ...

# %%
print(user_info.compare(book_key))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 print(user_info.compare(book_key))
#
# File ~\anaconda3\envs\ML_Project_5th\lib\site-packages\pandas\core\frame.py:7193, in DataFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    7080 @doc(
#    7081     _shared_docs["compare"],
#    7082     """
#    (...)
#    7191     keep_equal: bool = False,
#    7192 ) -> DataFrame:
# -> 7193     return super().compare(
#    7194         other=other,
#    7195         align_axis=align_axis,
#    7196         keep_shape=keep_shape,
#    7197         keep_equal=keep_equal,
#    7198     )
#
# File ~\anaconda3\envs\ML_Project_5th\lib\site-packages\pandas\core\generic.py:8640, in NDFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    8635     cls_self, cls_other = type(self).__name__, type(other).__name__
# ...

# %%
# for user_info['book_key'] == book_key['book_key']:
#     title.append(book_key['TITLE_INFO'])

if user_info['book_key'] == book_key['book_key']:
    title = []
    title.append(book_key['TITLE_INFO'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 4>()
#       1 # for user_info['book_key'] == book_key['book_key']:
#       2 #     title.append(book_key['TITLE_INFO'])
# ----> 4 if user_info['book_key'] == book_key['book_key']:
#       5     title = []
#       6     title.append(book_key['TITLE_INFO'])
#
# File ~\anaconda3\envs\ML_Project_5th\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\envs\ML_Project_5th\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# ...

# %%
user_info.merge(book_key, on='book_key')
# Out:
#      Unnamed: 0    rec_key   book_key  \
# 0        241277  975881895  573960626
# 1        282769  976876233  573967018
# 2        286329  976965787  573969549
# 3        454798  836520147  661645681
# 4        498408  868573198  661645681
# ..          ...        ...        ...
# 221    15985258  679504193  561955963
# 222    15988360  680084605  562912178
# 223    18497648  623629621  611903013
# 224    18504981  623679167  602306369
# 225    18511569  623626713  613090588
#
#                                               user_key              loan_date  \
# 0    75c457c2532150b79c55b4619b98c3d6aaedba48617d31...  2022-03-15 12:00:00.0
# 1    d6776ab3ba90fedab8228a52f9560fee1469adad70b893...  2022-04-10 12:00:00.0
# 2    c45f176c944b6936e722c436a6681ebdfb0fbdf18eab10...  2022-04-13 12:00:00.0
# 3             CFC57C4A5E31172E3694BB44408210079E2E8CD8  2021-09-18 12:00:00.0
# 4             7F2CBC6D5190EBF672C2898BE7C3F7A35C765633  2021-11-16 12:00:00.0
# ...

# %%
user_info[user_info['book_key'] == 646987]
# Out:
#          Unnamed: 0  rec_key  book_key  \
# 3913642     3913642  2760741    646987
#
#                                          user_key              loan_date  \
# 3913642  3BD3BAF7D4EDF371794116410BD2C8E834E61C9B  2021-10-26 12:00:00.0
#
#                    return_date  lib_code loan_type_code return_type_code  \
# 3913642  2022-04-01 12:00:00.0      4600           일반대출             연체반납
#
#               return_plan_date reservation_date reservation_expire_date  \
# 3913642  2021-11-09 12:00:00.0              NaN                     NaN
#
#         status l_device r_device manage_code loan_manage_code  \
# 3913642    대출중     무인기기     무인기기      111314           111314
#
#         return_manage_code  master_lib_code  title_info
# 3913642             111314             4600           0

# %%
df2 = pd.read_csv('../data2/NL_BO_SPECIES_MASTER_NEW_202112.csv')

# %%
display(user_info)
# Out:
#           Unnamed: 0     rec_key    book_key  \
# 0                  0  1822450338  1699774223
# 1                  1  1823175933  1625377432
# 2                  2  1822450339  1699774321
# 3                  3  1823176082  1616331145
# 4                  4  1822450340  1689903085
# ...              ...         ...         ...
# 18543496    18543496    21456926     1014584
# 18543497    18543497    21456927     1255870
# 18543498    18543498    21456941     1312375
# 18543499    18543499    21456942     1312377
# 18543500    18543500     9829482      125122
#
#                                           user_key              loan_date  \
# 0         D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F  2022-03-31 12:00:00.0
# 1         C0149AC77AF2058BCA3E07FE765A0E30837261EA  2022-04-19 12:00:00.0
# 2         D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F  2022-03-31 12:00:00.0
# 3         E1A7C4AF8B9356CE5A15199E17707545DD7D76DB  2022-04-19 12:00:00.0
# ...

# %%
user_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18543501 entries, 0 to 18543500
# Data columns (total 20 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Unnamed: 0               int64
#  1   rec_key                  int64
#  2   book_key                 int64
#  3   user_key                 object
#  4   loan_date                object
#  5   return_date              object
#  6   lib_code                 int64
#  7   loan_type_code           object
#  8   return_type_code         object
#  9   return_plan_date         object
#  10  reservation_date         object
#  11  reservation_expire_date  object
#  12  status                   object
#  13  l_device                 object
#  14  r_device                 object
#  15  manage_code              object
#  16  loan_manage_code         object
#  17  return_manage_code       object
#  18  master_lib_code          int64
#  19  title_info               int64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157118 entries, 0 to 157117
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   master_seq      157118 non-null  int64
#  1   isbn13          157118 non-null  int64
#  2   vol             39708 non-null   object
#  3   title           157118 non-null  object
#  4   author          157039 non-null  object
#  5   publisher       151577 non-null  object
#  6   pub_date        0 non-null       float64
#  7   add_code        129589 non-null  object
#  8   price           111394 non-null  float64
#  9   img_url         98337 non-null   object
#  10  description     84205 non-null   object
#  11  kdc_class_no    143057 non-null  float64
#  12  title_replace   148739 non-null  object
#  13  author_replace  149217 non-null  object
#  14  pub_date_2      103518 non-null  object
#  15  is_coll_aladin  154554 non-null  object
# ...

# %%
df5 = pd.merge(df2, book_key, on='isbn13', how='inner', suffixes=['_left', '_right'])
display(df5)

# %%
rec_key

# %%
df2.rename(columns = {'master_seq      ':'rec_key'},inplace=True)
display(df5.head())
# Out:
#    Unnamed: 0    rec_key   book_key  \
# 0      241277  975881895  573960626
# 1      282769  976876233  573967018
# 2      286329  976965787  573969549
# 3      454798  836520147  661645681
# 4      498408  868573198  661645681
#
#                                             user_key              loan_date  \
# 0  75c457c2532150b79c55b4619b98c3d6aaedba48617d31...  2022-03-15 12:00:00.0
# 1  d6776ab3ba90fedab8228a52f9560fee1469adad70b893...  2022-04-10 12:00:00.0
# 2  c45f176c944b6936e722c436a6681ebdfb0fbdf18eab10...  2022-04-13 12:00:00.0
# 3           CFC57C4A5E31172E3694BB44408210079E2E8CD8  2021-09-18 12:00:00.0
# 4           7F2CBC6D5190EBF672C2898BE7C3F7A35C765633  2021-11-16 12:00:00.0
#
#              return_date  lib_code loan_type_code return_type_code  \
# 0  2022-04-05 12:00:00.0       301              3              3.0
# 1                    NaN       301              3              NaN
# 2  2022-04-27 12:00:00.0       301              0              0.0
# ...

# %%
df10 = pd.merge(df2, user_info, on='rec_key', how='inner', suffixes=['_left', '_right'])
display(df10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 df10 = pd.merge(df2, user_info, on='rec_key', how='inner', suffixes=['_left', '_right'])
#       2 display(df10)
#
# File ~\anaconda3\envs\ML_Project_5th\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
# ...
