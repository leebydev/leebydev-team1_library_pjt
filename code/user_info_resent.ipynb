# %%
import os
print(os.getcwd())

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# c:\jupyter_home\통합프로젝트\book_list\code

# %%
import pandas as pd

# %%
cd G:\통합프로젝트\data2
# Out:
# G:\통합프로젝트\data2

# %%
os.listdir('../data2')
# Out:
# ['user_info_11.csv',
#  'user_info_12.csv',
#  'user_info_13.csv',
#  'user_info_14.csv',
#  'user_info_15.csv',
#  'user_info_16.csv',
#  'user_info_17.csv',
#  'user_info_18.csv',
#  'user_info_19.csv',
#  'user_info_20.csv']

# %%
forders = os.listdir('../data2')

# %%
cd ../data2
# Out:
# G:\통합프로젝트\data2

# %%
import os

path = '../data2/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + i, error_bad_lines=False)
    df = pd.concat([df,data])
    
df = df.reset_index(drop = True)

# %%
df
# Out:
#              rec_key    book_key                                  user_key  \
# 0         1822450338  1699774223  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 1         1823175933  1625377432  C0149AC77AF2058BCA3E07FE765A0E30837261EA
# 2         1822450339  1699774321  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3         1823176082  1616331145  E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4         1822450340  1689903085  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# ...              ...         ...                                       ...
# 18543496    21456926     1014584                  2A3134313230303030303930
# 18543497    21456927     1255870                  2A3134313230303030303930
# 18543498    21456941     1312375                  2A3231313130303030343131
# 18543499    21456942     1312377                  2A3231313130303030343131
# 18543500     9829482      125122                  2A3036303230303031333330
#
#                       loan_date            return_date  lib_code  \
# 0         2022-03-31 12:00:00.0  2022-04-18 12:00:00.0      1624
# 1         2022-04-19 12:00:00.0  2022-04-21 12:00:00.0      1623
# 2         2022-03-31 12:00:00.0  2022-04-18 12:00:00.0      1624
# 3         2022-04-19 12:00:00.0  2022-04-22 12:00:00.0      1623
# 4         2022-03-31 12:00:00.0  2022-04-18 12:00:00.0      1624
# ...                         ...                    ...       ...
# 18543496  2022-04-29 12:00:00.0                    NaN     25900
# 18543497  2022-04-29 12:00:00.0                    NaN     25900
# 18543498  2022-04-29 12:00:00.0                    NaN     25900
# 18543499  2022-04-29 12:00:00.0                    NaN     25900
# 18543500  2013-12-01 12:00:00.0  2022-04-21 12:00:00.0     25900
#
#          loan_type_code return_type_code       return_plan_date  \
# 0                     3              3.0  2022-04-14 12:00:00.0
# 1                     3              3.0  2022-05-03 12:00:00.0
# 2                     3              3.0  2022-04-14 12:00:00.0
# 3                     0              0.0  2022-05-03 12:00:00.0
# 4                     3              3.0  2022-04-14 12:00:00.0
# ...                 ...              ...                    ...
# 18543496           일반대출              대출중  2022-05-13 12:00:00.0
# 18543497           일반대출              대출중  2022-05-13 12:00:00.0
# 18543498           일반대출              대출중  2022-05-13 12:00:00.0
# 18543499           일반대출              대출중  2022-05-13 12:00:00.0
# 18543500           일반대출             연체반납  2013-12-22 12:00:00.0
#
#          reservation_date reservation_expire_date status  l_device  r_device  \
# 0                     NaN                     NaN      1   SMARTID   SMARTID
# 1                     NaN                     NaN      1  KOLASIII  KOLASIII
# 2                     NaN                     NaN      1   SMARTID   SMARTID
# 3                     NaN                     NaN      R  KOLASIII  KOLASIII
# 4                     NaN                     NaN      1   SMARTID   SMARTID
# ...                   ...                     ...    ...       ...       ...
# 18543496              NaN                     NaN    대출중      ILUS      ILUS
# 18543497              NaN                     NaN    대출중      ILUS      ILUS
# 18543498              NaN                     NaN    대출중      ILUS      ILUS
# 18543499              NaN                     NaN    대출중      ILUS      ILUS
# 18543500              NaN                     NaN    대출중      ILUS      ILUS
#
#          manage_code loan_manage_code return_manage_code  master_lib_code
# 0                 MZ               MZ                 MZ             1600
# 1                 MY              NaN                NaN             1600
# 2                 MZ               MZ                 MZ             1600
# 3                 MY               MY                 MY             1600
# 4                 MZ               MZ                 MZ             1600
# ...              ...              ...                ...              ...
# 18543496    A0000000         A0000000                NaN            25900
# 18543497    A0000000         A0000000                NaN            25900
# 18543498    A0000000         A0000000                NaN            25900
# 18543499    A0000000         A0000000                NaN            25900
# 18543500    A0000000         A0000000           A0000000            25900
#
# [18543501 rows x 18 columns]

# %%
df.to_csv('../data2/user_info_reset.csv')
