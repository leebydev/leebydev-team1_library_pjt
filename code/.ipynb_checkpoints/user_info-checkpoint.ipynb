# %%
cd ..
# Out:
# c:\jupyter_home\통합프로젝트\book_list

# %%
import os
print(os.getcwd())

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# c:\jupyter_home\통합프로젝트\book_list

# %%
import pandas as pd

# %%
cd G:\통합프로젝트\data
# Out:
# G:\통합프로젝트\data

# %%
os.listdir('../data')
# Out:
# ['user_info_01.csv',
#  'user_info_02.csv',
#  'user_info_03.csv',
#  'user_info_04.csv',
#  'user_info_05.csv',
#  'user_info_06.csv',
#  'user_info_07.csv',
#  'user_info_08.csv',
#  'user_info_09.csv',
#  'user_info_10.csv']

# %%
forders = os.listdir('../data')

# %%
cd ../data
# Out:
# G:\통합프로젝트\data

# %%
import os

path = '../data/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + i, error_bad_lines=False)
    df = pd.concat([df,data])
    
df = df.reset_index(drop = True)

# %%
df.to_csv('../data/user_info_final.csv')

# %%
df
# Out:
#              rec_key    book_key  \
# 0         1022668689   298812849
# 1         1031582388  1026808171
# 2         1022668707   200179336
# 3         1007441815   200218895
# 4         1022668709   200194527
# ...              ...         ...
# 18356835    86996919    75530846
# 18356836    86996920    82674635
# 18356837    86996921    82674623
# 18356838    86996922    81576013
# 18356839    86996923    82674627
#
#                                                    user_key  \
# 0                  3D1E0CF0B19216595D1C23B1C383E812D08B0E35
# 1                  2E0991F8C679EDA5DE0E5EA07B069E0FB1078A09
# 2                  F8375AC1659B3C80A640F83A1CD199E6DA92071E
# 3                  DB75AEC4EC036AF1200153A45500BECCF55DEAF7
# 4                  F8375AC1659B3C80A640F83A1CD199E6DA92071E
# ...                                                     ...
# 18356835  7d3886e599be56e5e1131960a5a026560e87d85e98e431...
# 18356836  7d3886e599be56e5e1131960a5a026560e87d85e98e431...
# ...

# %%
import os
print(os.getcwd())

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# G:\통합프로젝트\data

# %%
cd C:\jupyter_home\통합프로젝트\book_list
# Out:
# C:\jupyter_home\통합프로젝트\book_list

# %%
df = pd.read_csv('./data/user_info/user_info_final.csv')

# %%
df.drop_duplicates(['user_key'])
# Out:
#           Unnamed: 0     rec_key    book_key  \
# 0                  0  1022668689   298812849
# 1                  1  1031582388  1026808171
# 2                  2  1022668707   200179336
# 3                  3  1007441815   200218895
# 6                  6  1022668740  1007459068
# ...              ...         ...         ...
# 18356143    18356143    86989298    75582512
# 18356257    18356257    86990358    70184510
# 18356318    18356318    86991214    86425859
# 18356602    18356602    86994475    82407401
# 18356700    18356700    86995386    76566865
#
#                                                    user_key  \
# 0                  3D1E0CF0B19216595D1C23B1C383E812D08B0E35
# 1                  2E0991F8C679EDA5DE0E5EA07B069E0FB1078A09
# 2                  F8375AC1659B3C80A640F83A1CD199E6DA92071E
# 3                  DB75AEC4EC036AF1200153A45500BECCF55DEAF7
# 6                  74E819BA1BCEAEFCC42329D57F1BF18A26E9DC09
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18356840 entries, 0 to 18356839
# Data columns (total 19 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Unnamed: 0               int64
#  1   rec_key                  int64
#  2   book_key                 int64
#  3   user_key                 object
#  4   loan_date                object
#  5   return_date              object
#  6   lib_code                 int64
#  7   loan_type_code           object
#  8   return_type_code         object
#  9   return_plan_date         object
#  10  reservation_date         object
#  11  reservation_expire_date  object
#  12  status                   object
#  13  l_device                 object
#  14  r_device                 object
#  15  manage_code              object
#  16  loan_manage_code         object
#  17  return_manage_code       object
#  18  master_lib_code          int64
# dtypes: int64(5), object(14)
# memory usage: 2.6+ GB

# %%
# 고유값 개수
df['lib_code'].nunique()
# Out:
# Unnamed: 0                 18356840
# rec_key                    18346126
# book_key                    4275759
# user_key                     749314
# loan_date                      8124
# return_date                    8220
# lib_code                        389
# loan_type_code                   28
# return_type_code                 20
# return_plan_date               7314
# reservation_date               6500
# reservation_expire_date        6054
# status                           32
# l_device                        463
# r_device                        499
# manage_code                     183
# loan_manage_code                231
# return_manage_code              218
# master_lib_code                  64
# dtype: int64

# %%
lib_code = df.groupby('lib_code')

# %%
lib_code

# %%
lib_code = lib_code.size()

# %%
lib_code
# Out:
# lib_code
# 18001    5828512
# 18003     898626
# 18004    3323185
# 18005    1871970
# 18010     121893
#           ...
# 31509      12219
# 31510      25426
# 31511      27885
# 31512       6389
# 31513       8947
# Length: 389, dtype: int64

# %%
lib_code > 100000
# Out:
# lib_code
# 18001     True
# 18003     True
# 18004     True
# 18005     True
# 18010     True
#          ...
# 31509    False
# 31510    False
# 31511    False
# 31512    False
# 31513    False
# Length: 389, dtype: bool

# %%
import os
print(os.getcwd())
# Out:
# C:\jupyter_home\통합프로젝트\book_list

# %%
df_test = pd.read_csv('./data/user_info_20.csv')
df_test
# Out:
#              rec_key     book_key  \
# 0        34054051901  22118937063
# 1         1067148841   1027957508
# 2        34054051905  22119494887
# 3         1067148922   1039432988
# 4        34054051919  22118937069
# ...              ...          ...
# 1954276     21456926      1014584
# 1954277     21456927      1255870
# 1954278     21456941      1312375
# 1954279     21456942      1312377
# 1954280      9829482       125122
#
#                                                   user_key  \
# 0        49275075432247d4b0d5dbb36d8fcaf5ac75cf6888bda8...
# 1                 E7A92173FAD5CBB9FF76E1743CC0F14C0F9B22C0
# 2        49275075432247d4b0d5dbb36d8fcaf5ac75cf6888bda8...
# 3                 88BEB766F5F383AB643430E125117D3771C84982
# 4        49275075432247d4b0d5dbb36d8fcaf5ac75cf6888bda8...
# ...                                                    ...
# 1954276                           2A3134313230303030303930
# 1954277                           2A3134313230303030303930
# ...

# %%
user_data = pd.read_csv('./data/NL_CO_LOAN_PUB_202203-7.csv')
user_data
# Out:
#                  rec_key         book_key  \
# 0        250000492565454  200001023241549
# 1               86180393         83677592
# 2        250000492565501  200001024100765
# 3               86180394         83064549
# 4        250000492566191  200001015551685
# ...                  ...              ...
# 1946425        216669280         78061758
# 1946426        216669281         78061578
# 1946427        216669283         82293649
# 1946428        216669306         78061576
# 1946429        216669630         78038180
#
#                                                   user_key  \
# 0        d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
# 1        00e93e204fc1285f67e7a8f792182296571e1868ce1e1f...
# 2        d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
# 3        00e93e204fc1285f67e7a8f792182296571e1868ce1e1f...
# 4        d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
# ...                                                    ...
# ...

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946430 entries, 0 to 1946429
# Data columns (total 18 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   rec_key                  int64
#  1   book_key                 int64
#  2   user_key                 object
#  3   loan_date                object
#  4   return_date              object
#  5   lib_code                 int64
#  6   loan_type_code           object
#  7   return_type_code         object
#  8   return_plan_date         object
#  9   reservation_date         object
#  10  reservation_expire_date  object
#  11  status                   object
#  12  l_device                 object
#  13  r_device                 object
#  14  manage_code              object
#  15  loan_manage_code         object
#  16  return_manage_code       object
#  17  master_lib_code          int64
# dtypes: int64(4), object(14)
# memory usage: 267.3+ MB

# %%
user_data = user_data[['rec_key','user_key','loan_date','return_date','lib_code','l_device','r_device']]

# %%
display(user_data.head())
# Out:
#            rec_key                                           user_key  \
# 0  250000492565454  d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
# 1         86180393  00e93e204fc1285f67e7a8f792182296571e1868ce1e1f...
# 2  250000492565501  d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
# 3         86180394  00e93e204fc1285f67e7a8f792182296571e1868ce1e1f...
# 4  250000492566191  d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
#
#                loan_date            return_date  lib_code  l_device  r_device
# 0  2022-02-17 12:00:00.0  2022-03-05 12:00:00.0     29910  FASELF03  FASELF03
# 1  2016-07-22 12:00:00.0  2016-07-27 12:00:00.0     28202  KOLASIII  KOLASIII
# 2  2022-02-17 12:00:00.0  2022-03-05 12:00:00.0     29910  FASELF03  FASELF03
# 3  2016-07-22 12:00:00.0  2016-07-27 12:00:00.0     28202  KOLASIII  KOLASIII
# 4  2022-02-17 12:00:00.0  2022-03-05 12:00:00.0     29910  FASELF03  FASELF03

# %%
user_data = user_data[['rec_key','user_key','loan_date','return_date','lib_code']]
display(user_data.head())
# Out:
#            rec_key                                           user_key  \
# 0  250000492565454  d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
# 1         86180393  00e93e204fc1285f67e7a8f792182296571e1868ce1e1f...
# 2  250000492565501  d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
# 3         86180394  00e93e204fc1285f67e7a8f792182296571e1868ce1e1f...
# 4  250000492566191  d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
#
#                loan_date            return_date  lib_code
# 0  2022-02-17 12:00:00.0  2022-03-05 12:00:00.0     29910
# 1  2016-07-22 12:00:00.0  2016-07-27 12:00:00.0     28202
# 2  2022-02-17 12:00:00.0  2022-03-05 12:00:00.0     29910
# 3  2016-07-22 12:00:00.0  2016-07-27 12:00:00.0     28202
# 4  2022-02-17 12:00:00.0  2022-03-05 12:00:00.0     29910

# %%
print(user_data['user_key'].unique())
# Out:
# ['d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71efb97978d0bc9f2d8abc'
#  '00e93e204fc1285f67e7a8f792182296571e1868ce1e1fc7fd8c5187d0c16d9d'
#  '49ca912944f07308db61540cc6c764843e73cb60688d71b1b87ba5762643777b' ...
#  'D7C454E24E3E365B63F33A36CCA26A28722FCF3B'
#  '0499BA340FB16C7EAE7F30A9896632454E818DDA'
#  '5A4A8000A7E91FE664FED3349417CBF385E65A27']

# %%
print(user_data['user_key'].value_counts())
# Out:
# 26b27cd5a0e21aa3374fd4bb947a3fa4aa94bc80491599b3f4b0b272dd420ab7    8790
# 82c7866e509a87b6acbf350c44e01a73e6db410f6d23b6e9e992aebe993407db    5746
# 7ca0b1d8ed2236158196e3518d83440ff9496d22db5a50a6ac379a071964dc25    4019
# 0ea41ba6e3ffb3ca21beb3f6cce9c998f8eb2f5580549ff6374f0adc5cf71f20    3722
# 7375ce5a4ccee1db3b9a8cbfb31bfc3702d69c83cbd4c58b86b54e746876a9fe    2727
#                                                                     ...
# 39e785d28ae3f7991f3b207795786844ebc8cf8adbf7ce392062685cbdaad7f5       1
# 4105ead9681a70e870a9ef2a6d65556e9d4b0865c1de8755e78062f99eec37f8       1
# 36C4779DD876E571D8B788D8062EFE30CD589BD2                               1
# e6d567231d272f7cf4bb88ba876734e52fc672effd7e49c1398e27b58226b600       1
# 5A4A8000A7E91FE664FED3349417CBF385E65A27                               1
# Name: user_key, Length: 209220, dtype: int64

# %%
df = pd.read_csv('./data/NL_CO_LOAN_PUB_202203-7.csv')
df
# Out:
#                  rec_key         book_key  \
# 0        250000492565454  200001023241549
# 1               86180393         83677592
# 2        250000492565501  200001024100765
# 3               86180394         83064549
# 4        250000492566191  200001015551685
# ...                  ...              ...
# 1946425        216669280         78061758
# 1946426        216669281         78061578
# 1946427        216669283         82293649
# 1946428        216669306         78061576
# 1946429        216669630         78038180
#
#                                                   user_key  \
# 0        d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
# 1        00e93e204fc1285f67e7a8f792182296571e1868ce1e1f...
# 2        d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
# 3        00e93e204fc1285f67e7a8f792182296571e1868ce1e1f...
# 4        d19ba186ca3509e31efd5935744e21d3cadb5fc6ba71ef...
# ...                                                    ...
# ...
