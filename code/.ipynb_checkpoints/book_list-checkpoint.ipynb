# %%
import os
print(os.getcwd())

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# c:\jupyter_home\통합프로젝트\book_list\code

# %%
import pandas as pd

# %%
os.listdir('../data')
# Out:
# ['book_list', 'user_info']

# %%
forders = os.listdir('../data')

# %%
cd ../data
# Out:
# c:\jupyter_home\통합프로젝트\book_list\data

# %%
import os

path = '../data/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + i, error_bad_lines=False)
    df = pd.concat([df,data])
    
df = df.reset_index(drop = True)
# Out:
# b'Skipping line 783401: expected 11 fields, saw 16\n'
# b'Skipping line 2002736: expected 11 fields, saw 16\n'

# %%
display(df)
# Out:
#          ?master_seq         isbn13    vol  \
# 0          5126174.0  9781402045042    ebk
# 1          5126175.0  9780415332798    pbk
# 2          5126176.0  9780203401378    ebk
# 3          5126177.0  9781597450126  eisbn
# 4          5126178.0  9780878931897    hbk
# ...              ...            ...    ...
# 7597268          NaN  9781191496148    NaN
# 7597269          NaN  9781161755015    NaN
# 7597270          NaN  9781197192907    NaN
# 7597271          NaN  9781188005384    NaN
# 7597272          NaN  9781191334426    NaN
#
#                                                      title  \
# 0        (The)ecology of transportation:managing mobili...
# 1                                               Ecosystems
# 2                                               Ecosystems
# 3            Epidermal growth factor:methods and protocols
# 4                                     Evolutionary biology
# ...                                                    ...
# ...

# %%
df.columns
# Out:
# Index(['?master_seq', 'isbn13', 'vol', 'title', 'author', 'publisher',
#        'pub_date', 'add_code', 'price', 'img_url', 'description', 'master_seq',
#        'kdc_class_no', 'title_replace', 'author_replace', 'pub_date_2',
#        'is_coll_aladin', 'is_coll_naver', 'isbn_origin'],
#       dtype='object')

# %%
df = df[df['add_code'].notna()]

# %%
df
# Out:
#          ?master_seq         isbn13  vol               title  \
# 23         5126197.0  9788958945116    1  폭마전기 :정재은 新무협 장편소설
# 24         5126198.0  9788953278974    1          신곡주계 폴리포니카
# 25         5126199.0  9788953279506    2          신곡주계 폴리포니카
# 26         5126200.0  9788953280250    3          신곡주계 폴리포니카
# 27         5126201.0  9788953284890    4          신곡주계 폴리포니카
# ...              ...            ...  ...                 ...
# 7597078          NaN  9791189850142  NaN      임복근 동화선집(지역작가)
# 7597082          NaN  9798997766963  NaN  Faith-Praxis 실천 신앙
# 7597097          NaN  9788986986273  NaN    배 병우 Bae, Bien-U
# 7597102          NaN  9788993518924  NaN        국립중앙박물관 상설전시
# 7597114          NaN  9788993518931  NaN            아시아를 칠하다
#
#                      author publisher   pub_date add_code price  \
# 23                      정재은    마루 출판사  2007-2008    04810   NaN
# 24       사카키 이치로 지음 ;이형선 옮김     서울문화사  2007-2014    04830   NaN
# ...

# %%
df.isnull().sum()
# Out:
# ?master_seq       2385907
# isbn13                539
# vol               3027134
# title                1227
# author              20682
# publisher          260106
# pub_date          2375031
# add_code                0
# price             1124417
# img_url           1376769
# description       1714259
# master_seq        1684826
# kdc_class_no      1825981
# title_replace     2054606
# author_replace    2932089
# pub_date_2        2404161
# is_coll_aladin    1707228
# is_coll_naver     1707228
# isbn_origin       2251057
# dtype: int64

# %%
df.drop_duplicates(['title'])
df
# Out:
#          ?master_seq         isbn13  vol               title  \
# 23         5126197.0  9788958945116    1  폭마전기 :정재은 新무협 장편소설
# 24         5126198.0  9788953278974    1          신곡주계 폴리포니카
# 25         5126199.0  9788953279506    2          신곡주계 폴리포니카
# 26         5126200.0  9788953280250    3          신곡주계 폴리포니카
# 27         5126201.0  9788953284890    4          신곡주계 폴리포니카
# ...              ...            ...  ...                 ...
# 7597078          NaN  9791189850142  NaN      임복근 동화선집(지역작가)
# 7597082          NaN  9798997766963  NaN  Faith-Praxis 실천 신앙
# 7597097          NaN  9788986986273  NaN    배 병우 Bae, Bien-U
# 7597102          NaN  9788993518924  NaN        국립중앙박물관 상설전시
# 7597114          NaN  9788993518931  NaN            아시아를 칠하다
#
#                      author publisher   pub_date add_code price  \
# 23                      정재은    마루 출판사  2007-2008    04810   NaN
# 24       사카키 이치로 지음 ;이형선 옮김     서울문화사  2007-2014    04830   NaN
# ...

# %%
df = df[df['kdc_class_no'].notna()]
df
# Out:
#          ?master_seq         isbn13          vol                       title  \
# 3178515          NaN  9788982412677          NaN         (Power up)액세스 프로그래밍
# 3178516          NaN  9788995192740          NaN  (2001-2002년)일본의 구조개혁과 증권시장
# 3178517          NaN  9788982412615          NaN     IBM 통합(Intergrated) 시스템
# 3178518          NaN  9788975486456          NaN            (L=MS²학문의 기원)學習學
# 3178519          NaN  9788982412738          NaN                  인터넷에 점포차리기
# ...              ...            ...          ...                         ...
# 7589490          NaN  9788972581222          12:                   특급추리뤼팽시리즈
# 7589491          NaN  9788983311634  1-1 - 1-24/                  두리의 우주선 여행
# 7589492          NaN  9788983311511          114                  두리의 우주선 여행
# 7589504          NaN  9788971962305            1                  산수보다 쉬운 수학
# 7589505          NaN  9788971962312            2                  산수보다 쉬운 수학
#
# ...

# %%
isbn13 
title 
author
publisher       
add_code     
img_url
kdc_class_no      
title_replace     
author_replace

# %%
df.isna().sum()
# Out:
# ?master_seq       2242985
# isbn13                  0
# vol               1616826
# title                   0
# author               7743
# publisher          126819
# pub_date          2229176
# add_code                0
# price              603041
# img_url            749084
# description        928353
# master_seq              0
# kdc_class_no            0
# title_replace      366221
# author_replace    1177906
# pub_date_2         686803
# is_coll_aladin      22401
# is_coll_naver       22401
# isbn_origin        492949
# dtype: int64

# %%
book_list = df[['isbn13','title','author','publisher','add_code','img_url','kdc_class_no','title_replace','author_replace']]

# %%
book_list.isna().sum()
# Out:
# isbn13                  0
# title                   0
# author               7743
# publisher          126819
# add_code                0
# img_url            749084
# kdc_class_no            0
# title_replace      366221
# author_replace    1177906
# dtype: int64

# %%
book_list['author'] = book_list['author'].fillna('저자 미상')

# %%
book_list.isna().sum()
# Out:
# isbn13                  0
# title                   0
# author                  0
# publisher          126819
# add_code                0
# img_url            749084
# kdc_class_no            0
# title_replace      366221
# author_replace    1177906
# dtype: int64

# %%
book_list.to_csv('../data/book_list_final.csv')

# %%
book_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2242985 entries, 3178515 to 7589505
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   isbn13          object
#  1   title           object
#  2   author          object
#  3   publisher       object
#  4   add_code        object
#  5   img_url         object
#  6   kdc_class_no    object
#  7   title_replace   object
#  8   author_replace  object
# dtypes: object(9)
# memory usage: 171.1+ MB

# %%
df = pd.read_csv('../data/book_list/book_list_final.csv')
df.info()
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242985 entries, 0 to 2242984
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Unnamed: 0      int64
#  1   isbn13          object
#  2   title           object
#  3   author          object
#  4   publisher       object
#  5   add_code        object
#  6   img_url         object
#  7   kdc_class_no    object
#  8   title_replace   object
#  9   author_replace  object
# dtypes: int64(1), object(9)
# memory usage: 171.1+ MB
#    Unnamed: 0         isbn13                       title      author  \
# 0     3178515  9788982412677         (Power up)액세스 프로그래밍  박운재...[등]저
# 1     3178516  9788995192740  (2001-2002년)일본의 구조개혁과 증권시장      홍인기 지음
# 2     3178517  9788982412615     IBM 통합(Intergrated) 시스템  류성렬;한문희 공저
# 3     3178518  9788975486456            (L=MS²학문의 기원)學習學       韓駿相 著
# 4     3178519  9788982412738                  인터넷에 점포차리기   지란지교소프트 저
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242985 entries, 0 to 2242984
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Unnamed: 0      int64
#  1   isbn13          object
#  2   title           object
#  3   author          object
#  4   publisher       object
#  5   add_code        object
#  6   img_url         object
#  7   kdc_class_no    object
#  8   title_replace   object
#  9   author_replace  object
# dtypes: int64(1), object(9)
# memory usage: 171.1+ MB

# %%
df = df.drop(['title_replace','author_replace','img_url'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242985 entries, 0 to 2242984
# Data columns (total 7 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Unnamed: 0    int64
#  1   isbn13        object
#  2   title         object
#  3   author        object
#  4   publisher     object
#  5   add_code      object
#  6   kdc_class_no  object
# dtypes: int64(1), object(6)
# memory usage: 119.8+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# isbn13               0
# title                0
# author               0
# publisher       126819
# add_code             0
# kdc_class_no         0
# dtype: int64

# %%
df['publisher'].dropna()

# %%
df.isnull().sum()

# %%
df.to_csv('../data/book_list_final.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/book_list_final.csv')
# Out:
# C:\Users\yibob\AppData\Local\Temp\ipykernel_18784\3589907901.py:1: DtypeWarning: Columns (2,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/book_list_final.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242985 entries, 0 to 2242984
# Data columns (total 8 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Unnamed: 0.1  int64
#  1   Unnamed: 0    int64
#  2   isbn13        object
#  3   title         object
#  4   author        object
#  5   publisher     object
#  6   add_code      object
#  7   kdc_class_no  object
# dtypes: int64(2), object(6)
# memory usage: 136.9+ MB
