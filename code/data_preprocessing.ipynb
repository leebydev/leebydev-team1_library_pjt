# %%
import os
print(os.getcwd())

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# c:\jupyter_home\통합프로젝트\library\code

# %%
import pandas as pd
import numpy as np
import random

# %%
user_info = pd.read_csv('../data2/user_info_80000.csv')
book_info = pd.read_csv('../data2/book_info_80000.csv')

# %%
user_info = user_info.reset_index(drop=True)
display(user_info.head())
book_info = book_info.reset_index(drop=True)
display(book_info.head())
# Out:
#    Unnamed: 0                                  user_key  \
# 0           0  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 1           1  C0149AC77AF2058BCA3E07FE765A0E30837261EA
# 2           2  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3           3  E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4           4  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
#
#                loan_date            return_date
# 0  2022-03-31 12:00:00.0  2022-04-18 12:00:00.0
# 1  2022-04-19 12:00:00.0  2022-04-21 12:00:00.0
# 2  2022-03-31 12:00:00.0  2022-04-18 12:00:00.0
# 3  2022-04-19 12:00:00.0  2022-04-22 12:00:00.0
# 4  2022-03-31 12:00:00.0  2022-04-18 12:00:00.0
#    Unnamed: 0         isbn13                            title  \
# 0       10887  9788932105635                        주님의 기도:해설
# 1       10888  9788977990371                             建築技術
# 2       10891  9788932105567                          생명의 옹달샘
# 3       10912  9788931418828  전자상거래관리사 2급 필기 마스터바이블:전자상거래관련법규
# ...

# %%
display(user_info.head())
# Out:
#    Unnamed: 0                                  user_key  \
# 0           0  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 1           1  C0149AC77AF2058BCA3E07FE765A0E30837261EA
# 2           2  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3           3  E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4           4  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
#
#                loan_date            return_date
# 0  2022-03-31 12:00:00.0  2022-04-18 12:00:00.0
# 1  2022-04-19 12:00:00.0  2022-04-21 12:00:00.0
# 2  2022-03-31 12:00:00.0  2022-04-18 12:00:00.0
# 3  2022-04-19 12:00:00.0  2022-04-22 12:00:00.0
# 4  2022-03-31 12:00:00.0  2022-04-18 12:00:00.0

# %%
user_info2 = user_info.iloc[:, 1:]
book_info2 = book_info.iloc[:, 1:]
#display(user_info2.head())
#display(book_info2.head())

# %%
df = pd.concat([user_info2, book_info2], axis=1)
display(df.head())
len(df)
# Out:
#                                    user_key              loan_date  \
# 0  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F  2022-03-31 12:00:00.0
# 1  C0149AC77AF2058BCA3E07FE765A0E30837261EA  2022-04-19 12:00:00.0
# 2  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F  2022-03-31 12:00:00.0
# 3  E1A7C4AF8B9356CE5A15199E17707545DD7D76DB  2022-04-19 12:00:00.0
# 4  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F  2022-03-31 12:00:00.0
#
#              return_date         isbn13                            title  \
# 0  2022-04-18 12:00:00.0  9788932105635                        주님의 기도:해설
# 1  2022-04-21 12:00:00.0  9788977990371                             建築技術
# 2  2022-04-18 12:00:00.0  9788932105567                          생명의 옹달샘
# 3  2022-04-22 12:00:00.0  9788931418828  전자상거래관리사 2급 필기 마스터바이블:전자상거래관련법규
# 4  2022-04-18 12:00:00.0  9788988800980            이민 가서 뭐해 먹고 살지:뉴질랜드 편
#
#               author publisher  add_code  \
# 0  로마노 구아르디니 저;이석은 역    가톨릭출판사    3230.0
# ...

# %%
df2 = df.assign(sex=np.nan)
display(df2)
# Out:
#                                                 user_key  \
# 0               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 1               C0149AC77AF2058BCA3E07FE765A0E30837261EA
# 2               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3               E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# ...                                                  ...
# 79995           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79996  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79997           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79998  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79999           CB443B355CEF5567BD2091C2A6E1DA8928BDA23F
#
#                    loan_date            return_date         isbn13  \
# 0      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105635
# 1      2022-04-19 12:00:00.0  2022-04-21 12:00:00.0  9788977990371
# 2      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105567
# ...

# %%
df2.iloc[:40000, -1] = 0
df2.iloc[40000:80000, -1] = 1

# %%
display(df2)
# Out:
#                                                 user_key  \
# 0               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 1               C0149AC77AF2058BCA3E07FE765A0E30837261EA
# 2               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3               E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# ...                                                  ...
# 79995           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79996  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79997           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79998  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79999           CB443B355CEF5567BD2091C2A6E1DA8928BDA23F
#
#                    loan_date            return_date         isbn13  \
# 0      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105635
# 1      2022-04-19 12:00:00.0  2022-04-21 12:00:00.0  9788977990371
# 2      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105567
# ...

# %%
df2 = df2.assign(age=np.nan)
display(df2)
# Out:
#                                                 user_key  \
# 0               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 1               C0149AC77AF2058BCA3E07FE765A0E30837261EA
# 2               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3               E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# ...                                                  ...
# 79995           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79996  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79997           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79998  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79999           CB443B355CEF5567BD2091C2A6E1DA8928BDA23F
#
#                    loan_date            return_date         isbn13  \
# 0      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105635
# 1      2022-04-19 12:00:00.0  2022-04-21 12:00:00.0  9788977990371
# 2      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105567
# ...

# %%
df2.iloc[:20000, -1] = 0
df2.iloc[20000:40000, -1] = 1
df2.iloc[40000:60000, -1] = 2
df2.iloc[60000:80000, -1] = 3

display(df2.head())
display(df2.tail())
# Out:
#                                    user_key              loan_date  \
# 0  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F  2022-03-31 12:00:00.0
# 1  C0149AC77AF2058BCA3E07FE765A0E30837261EA  2022-04-19 12:00:00.0
# 2  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F  2022-03-31 12:00:00.0
# 3  E1A7C4AF8B9356CE5A15199E17707545DD7D76DB  2022-04-19 12:00:00.0
# 4  D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F  2022-03-31 12:00:00.0
#
#              return_date         isbn13                            title  \
# 0  2022-04-18 12:00:00.0  9788932105635                        주님의 기도:해설
# 1  2022-04-21 12:00:00.0  9788977990371                             建築技術
# 2  2022-04-18 12:00:00.0  9788932105567                          생명의 옹달샘
# 3  2022-04-22 12:00:00.0  9788931418828  전자상거래관리사 2급 필기 마스터바이블:전자상거래관련법규
# 4  2022-04-18 12:00:00.0  9788988800980            이민 가서 뭐해 먹고 살지:뉴질랜드 편
#
#               author publisher  add_code  \
# 0  로마노 구아르디니 저;이석은 역    가톨릭출판사    3230.0
# ...

# %%
#df2.to_csv('../data2/library_learning_dataset.csv', index = False)

# %% [markdown]
# ***

# %%
df = pd.read_csv('../data2/library_learning_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_key      80000 non-null  object
#  1   loan_date     80000 non-null  object
#  2   return_date   80000 non-null  object
#  3   isbn13        80000 non-null  int64
#  4   title         80000 non-null  object
#  5   author        80000 non-null  object
#  6   publisher     80000 non-null  object
#  7   add_code      80000 non-null  float64
#  8   img_url       80000 non-null  object
#  9   kdc_class_no  80000 non-null  float64
#  10  sex           80000 non-null  float64
#  11  age           80000 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 7.3+ MB

# %%
book_description = pd.read_csv('../data2/NL_BO_SPECIES_MASTER_NEW_202112.csv')
book_description.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157118 entries, 0 to 157117
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   master_seq      157118 non-null  int64
#  1   isbn13          157118 non-null  int64
#  2   vol             39708 non-null   object
#  3   title           157118 non-null  object
#  4   author          157039 non-null  object
#  5   publisher       151577 non-null  object
#  6   pub_date        0 non-null       float64
#  7   add_code        129589 non-null  object
#  8   price           111394 non-null  float64
#  9   img_url         98337 non-null   object
#  10  description     84205 non-null   object
#  11  kdc_class_no    143057 non-null  float64
#  12  title_replace   148739 non-null  object
#  13  author_replace  149217 non-null  object
#  14  pub_date_2      103518 non-null  object
#  15  is_coll_aladin  154554 non-null  object
# ...

# %%
book_description = book_description[['isbn13','description']]

# %%
book_description
# Out:
#                isbn13                                        description
# 0       9791156759270  2004년 방영한 애니메이션 &lt;달빛천사&gt;에서 주인공 루나(풀문) 역을 맡...
# 1       9791168120877  “그러니 나는 말하고 싶은 것을 말하겠다”「침착하게 사랑하기」 차도하 시인 첫 에세...
# 2       9791168120839  한중일 관계의 결정적 분기점인 임오군란의 막전 막후를 다룬다. 러시아의 세력 확장을...
# 3       9791168120846  누구에게나 기분 구급상자가 필요하다. 하나씩 하나씩 차근차근, 좋은 기분을 쌓고 건...
# 4       9791168120747  나다운 일상을 만드는 사람들의 이야기를 담은 『오늘도 리추얼』 시리즈가 위즈덤하우스...
# ...               ...                                                ...
# 157113  9781191496148                                                NaN
# 157114  9781161755015                                                NaN
# 157115  9781197192907                                                NaN
# 157116  9781188005384                                                NaN
# 157117  9781191334426                                                NaN
#
# [157118 rows x 2 columns]

# %%
df2 = pd.merge(df, book_description, how='inner', on='isbn13')

# %%
df2
# Out:
#                                                 user_key  \
# 0               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 1               C0149AC77AF2058BCA3E07FE765A0E30837261EA
# 2               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3               E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# ...                                                  ...
# 79995           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79996  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79997           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79998  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79999           CB443B355CEF5567BD2091C2A6E1DA8928BDA23F
#
#                    loan_date            return_date         isbn13  \
# 0      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105635
# 1      2022-04-19 12:00:00.0  2022-04-21 12:00:00.0  9788977990371
# 2      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105567
# ...

# %%
df2.isnull().sum()
# Out:
# user_key           0
# loan_date          0
# return_date        0
# isbn13             0
# title              0
# author             0
# publisher          0
# add_code           0
# img_url            0
# kdc_class_no       0
# sex                0
# age                0
# description     7912
# dtype: int64

# %%
de2 = df2.dropna()

# %%
de2
# Out:
#                                                 user_key  \
# 0               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 2               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3               E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 5               C5737B4888348AB2CF9F4A0F13B4A5F78EE232EA
# ...                                                  ...
# 79995           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79996  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79997           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79998  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79999           CB443B355CEF5567BD2091C2A6E1DA8928BDA23F
#
#                    loan_date            return_date         isbn13  \
# 0      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105635
# 2      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105567
# 3      2022-04-19 12:00:00.0  2022-04-22 12:00:00.0  9788931418828
# ...

# %%
de2.isnull().sum()
# Out:
# user_key        0
# loan_date       0
# return_date     0
# isbn13          0
# title           0
# author          0
# publisher       0
# add_code        0
# img_url         0
# kdc_class_no    0
# sex             0
# age             0
# description     0
# dtype: int64

# %%
de2
# Out:
#                                                 user_key  \
# 0               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 2               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3               E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 5               C5737B4888348AB2CF9F4A0F13B4A5F78EE232EA
# ...                                                  ...
# 79995           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79996  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79997           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79998  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79999           CB443B355CEF5567BD2091C2A6E1DA8928BDA23F
#
#                    loan_date            return_date         isbn13  \
# 0      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105635
# 2      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105567
# 3      2022-04-19 12:00:00.0  2022-04-22 12:00:00.0  9788931418828
# ...

# %%
test2 = de2['isbn13'].value_counts()

# %%
test = de2['isbn13'] == 9791136280381

# %%
de2.loc[test]
# Out:
#                                                 user_key  \
# 79998  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
#
#                    loan_date            return_date         isbn13   title  \
# 79998  2022-04-09 12:00:00.0  2022-04-21 12:00:00.0  9791136280381  그녀도 여친
#
#                   author publisher  add_code  \
# 79998  저자: 히로유키 ;번역: 이은주     대원씨아이    7830.0
#
#                                                  img_url  kdc_class_no  sex  \
# 79998  https://bookthumb-phinf.pstatic.net/cover/208/...         830.0  1.0
#
#        age                                        description
# 79998  3.0  인기 급상승 네오 스탠더드 러브 코미디 제3권!!마당에서 살기 시작한 미리카를 간신...

# %%
de2[test]
# Out:
#                                                 user_key  \
# 79998  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
#
#                    loan_date            return_date         isbn13   title  \
# 79998  2022-04-09 12:00:00.0  2022-04-21 12:00:00.0  9791136280381  그녀도 여친
#
#                   author publisher  add_code  \
# 79998  저자: 히로유키 ;번역: 이은주     대원씨아이    7830.0
#
#                                                  img_url  kdc_class_no  sex  \
# 79998  https://bookthumb-phinf.pstatic.net/cover/208/...         830.0  1.0
#
#        age                                        description
# 79998  3.0  인기 급상승 네오 스탠더드 러브 코미디 제3권!!마당에서 살기 시작한 미리카를 간신...

# %%
de2
# Out:
#                                                 user_key  \
# 0               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 2               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 3               E1A7C4AF8B9356CE5A15199E17707545DD7D76DB
# 4               D42A0AECF86DE543E159EBCF1F440F55BD9CEF5F
# 5               C5737B4888348AB2CF9F4A0F13B4A5F78EE232EA
# ...                                                  ...
# 79995           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79996  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79997           C1D878BD26A7D77D9AC00C3A636942E0C9358A16
# 79998  c2fe9251e1ced840e3eb0234d0517c0402837f7a68bdef...
# 79999           CB443B355CEF5567BD2091C2A6E1DA8928BDA23F
#
#                    loan_date            return_date         isbn13  \
# 0      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105635
# 2      2022-03-31 12:00:00.0  2022-04-18 12:00:00.0  9788932105567
# 3      2022-04-19 12:00:00.0  2022-04-22 12:00:00.0  9788931418828
# ...

# %%
de2['isbn13'] == '9788932105635'
# Out:
# 0        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 79995    False
# 79996    False
# 79997    False
# 79998    False
# 79999    False
# Name: isbn13, Length: 72088, dtype: bool

# %%
user_loan_info = pd.read_csv('../data2/user_loan_info.csv')
user_loan_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_key      80000 non-null  object
#  1   loan_date     80000 non-null  object
#  2   return_date   80000 non-null  object
#  3   isbn13        80000 non-null  int64
#  4   title         80000 non-null  object
#  5   author        80000 non-null  object
#  6   publisher     80000 non-null  object
#  7   add_code      80000 non-null  float64
#  8   img_url       80000 non-null  object
#  9   kdc_class_no  80000 non-null  float64
#  10  sex           80000 non-null  float64
#  11  age           80000 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 7.3+ MB

# %%
description_userinfo = pd.merge(user_loan_info, book_description, how='inner', on='isbn13')

# %%
description_userinfo
# Out:
#                                        user_key              loan_date  \
# 0                           4208654315914400000  2022-03-31 12:00:00.0
# 1                      149772058307765000000000  2022-04-19 12:00:00.0
# 2                           4208654315914400000  2022-03-31 12:00:00.0
# 3                     1748935651519910000000000  2022-04-19 12:00:00.0
# 4                           4208654315914400000  2022-03-31 12:00:00.0
# ...                                         ...                    ...
# 79995                18782677790036300000000000  2022-03-26 12:00:00.0
# 79996  2925118403023400000000000000000000000000  2022-04-09 12:00:00.0
# 79997                18782677790036300000000000  2022-03-26 12:00:00.0
# 79998  2925118403023400000000000000000000000000  2022-04-09 12:00:00.0
# 79999                   44335555672091200000000  2022-03-30 12:00:00.0
#
#                  return_date         isbn13  \
# 0      2022-04-18 12:00:00.0  9788932105635
# ...

# %%
description_userinfo = description_userinfo.dropna()

# %%
description_userinfo
# Out:
#                                        user_key              loan_date  \
# 0                           4208654315914400000  2022-03-31 12:00:00.0
# 2                           4208654315914400000  2022-03-31 12:00:00.0
# 3                     1748935651519910000000000  2022-04-19 12:00:00.0
# 4                           4208654315914400000  2022-03-31 12:00:00.0
# 5                      573748883482940000000000  2022-04-19 12:00:00.0
# ...                                         ...                    ...
# 79995                18782677790036300000000000  2022-03-26 12:00:00.0
# 79996  2925118403023400000000000000000000000000  2022-04-09 12:00:00.0
# 79997                18782677790036300000000000  2022-03-26 12:00:00.0
# 79998  2925118403023400000000000000000000000000  2022-04-09 12:00:00.0
# 79999                   44335555672091200000000  2022-03-30 12:00:00.0
#
#                  return_date         isbn13  \
# 0      2022-04-18 12:00:00.0  9788932105635
# ...

# %%
description_userinfo = pd.read_csv('../data2/library_dataset_loan_description.csv')

# %%
description_userinfo['kdc_class_no'] = description_userinfo['kdc_class_no'].astype(int)

# %%
description_userinfo
# Out:
#                                        user_key              loan_date  \
# 0                           4208654315914400000  2022-03-31 12:00:00.0
# 1                           4208654315914400000  2022-03-31 12:00:00.0
# 2                     1748935651519910000000000  2022-04-19 12:00:00.0
# 3                           4208654315914400000  2022-03-31 12:00:00.0
# 4                      573748883482940000000000  2022-04-19 12:00:00.0
# ...                                         ...                    ...
# 72083                18782677790036300000000000  2022-03-26 12:00:00.0
# 72084  2925118403023400000000000000000000000000  2022-04-09 12:00:00.0
# 72085                18782677790036300000000000  2022-03-26 12:00:00.0
# 72086  2925118403023400000000000000000000000000  2022-04-09 12:00:00.0
# 72087                   44335555672091200000000  2022-03-30 12:00:00.0
#
#                  return_date         isbn13  \
# 0      2022-04-18 12:00:00.0  9788932105635
# ...

# %%
#description_userinfo.to_csv('../data2/library_dataset_loan_description.csv', index = False)

# %% [markdown]
# ***
